# %% [raw]
# ---
# description: Functions for gathering data to train and for using tokenization machine
#   learning models.
# output-file: markdown.obsidian.personal.machine_learning.tokenize.__init__.html
# title: machine_learning.tokenize
#
# ---

# %%
#| default_exp machine_learning.tokenize.__init__

# %%
#| export
