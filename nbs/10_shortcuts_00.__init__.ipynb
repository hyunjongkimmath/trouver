# %% [raw]
# ---
# description: Shortcut functions that may be convenient to invoke on user-written scripts
# output-file: shortcuts_00.__init__.html
# title: shortcuts
#
# ---

# %%
#| default_exp shortcuts.__init__
