# %% [raw]
# ---
# description: Utility functions for dealing with typos that might appear, say when
#   typing.
# output-file: helper_05.typos.html
# title: helper.typos
#
# ---

# %%
#| default_exp helper.typos
