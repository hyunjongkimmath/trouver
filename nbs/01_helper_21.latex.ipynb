# %% [raw]
# ---
# description: Helper functions for latex functionalities
# output-file: helper_21.latex.html
# title: helper.latex
#
# ---

# %%
#| default_exp helper.latex.__init__

# %% [markdown]
# We remark that many of the functions in this module are AI generated or assisted.

# %%
#| export
import random
import re
import string
from typing import Callable, List, Optional, Union

from Levenshtein import distance

from trouver.helper import sublist_generator
from trouver.helper.regex import latex_indices, replace_string_by_indices
from trouver.helper.latex.macros_and_commands import extract_latex_commands

# %%
from fastcore.test import *
