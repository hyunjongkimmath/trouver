# %% [raw]
# ---
# description: Functions that apply for one's personal Obsidian.md math vault.
# output-file: personal_vault_00.__init__.html
# title: markdown.obisidian.personal
#
# ---

# %%
#| default_exp markdown.obsidian.personal.__init__
